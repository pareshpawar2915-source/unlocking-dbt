# %% [markdown]
# <a href="https://colab.research.google.com/github/pareshpawar2915-source/unlocking-dbt/blob/main/ray_ml_anyscale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda --version
# Out:
# conda 24.11.2

# %%
# !mamba install python=3.13 ray-default -c conda-forge
# Out:
# Looking for: ['python=3.13', 'ray-default']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# Your pinning does not match what's currently installed. Please remove the pin and fix your installation
#   Pin: python=3.12
#   Currently installed: conda-forge/linux-64::python==3.11.11=h9e4cc4f_1_cpython

# %%
# !mamba create -n ray-jupyter python=3.13 ray-default -y
# Out:
# Looking for: ['python=3.13', 'ray-default']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# Transaction
#
#   Prefix: /usr/local/envs/ray-jupyter
#
#   Updating specs:
#
#    - python=3.13
#    - ray-default
#
#
#   Package                                  Version  Build                 Channel           Size
# ──────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────────────────────────
#
#   + python_abi                                3.13  8_cp313               conda-forge        7kB
#   + tzdata                                   2025c  hc9c84f9_1            conda-forge      119kB
#   + ca-certificates                       2026.1.4  hbd8a1cb_0            conda-forge      147kB
#   + _libgcc_mutex                              0.1  conda_forge           conda-forge     Cached
#   + libgomp                                 15.2.0  he0feb66_16           conda-forge      603kB
#   + _openmp_mutex                              4.5  2_gnu                 conda-forge     Cached
#   + libgcc                                  15.2.0  he0feb66_16           conda-forge        1MB
#   + libmpdec                                 4.0.0  hb9d3cd8_0            conda-forge       91kB
#   + c-ares                                  1.34.6  hb03c661_0            conda-forge      208kB
#   + openssl                                  3.6.0  h26f9b46_0            conda-forge        3MB
#   + ncurses                                    6.5  h2d0b736_3            conda-forge      892kB
#   + libzlib                                  1.3.1  hb9d3cd8_2            conda-forge     Cached
#   + libuuid                                 2.41.3  h5347b49_0            conda-forge       40kB
#   + liblzma                                  5.8.1  hb9d3cd8_2            conda-forge      113kB
#   + bzip2                                    1.0.8  hda65f42_8            conda-forge      260kB
#   + yaml                                     0.2.5  h280c20c_3            conda-forge       85kB
#   + libstdcxx                               15.2.0  h934c35e_16           conda-forge        6MB
#   + libffi                                   3.5.2  h9ec8514_0            conda-forge       58kB
#   + libexpat                                 2.7.3  hecca717_0            conda-forge       77kB
#   + readline                                   8.3  h853b02a_0            conda-forge      345kB
#   + zstd                                     1.5.7  hb78ec9c_6            conda-forge      601kB
#   + tk                                      8.6.13  noxft_ha0e22de_103    conda-forge        3MB
#   + icu                                       78.1  h33c6efd_0            conda-forge       13MB
#   + libunwind                                1.8.3  h65a8314_0            conda-forge       76kB
#   + libabseil                           20250512.1  cxx17_hba17884_0      conda-forge        1MB
#   + ld_impl_linux-64                          2.45  default_hbd61a6d_105  conda-forge      731kB
#   + libsqlite                               3.51.1  hf4e2dac_1            conda-forge      943kB
#   + py-spy                                   0.4.1  he182f42_0            conda-forge        2MB
#   + libprotobuf                             6.31.1  h49aed37_4            conda-forge        4MB
#   + libre2-11                           2025.11.05  h7b12aa8_0            conda-forge      211kB
#   + python                                 3.13.11  hc97d973_100_cp313    conda-forge       37MB
#   + re2                                 2025.11.05  h5301d42_0            conda-forge       27kB
#   + libgrpc                                 1.73.1  h3288cfb_1            conda-forge        8MB
#   + pip                                       25.3  pyh145f28c_0          conda-forge        1MB
#   + six                                     1.17.0  pyhe01879c_1          conda-forge       18kB
#   + pyasn1                                   0.6.1  pyhd8ed1ab_2          conda-forge       62kB
#   + pycparser                                 2.22  pyh29332c3_1          conda-forge     Cached
#   + cachetools                               6.2.4  pyhd8ed1ab_0          conda-forge       17kB
#   + pysocks                                  1.7.1  pyha55dd90_7          conda-forge     Cached
#   + hyperframe                               6.1.0  pyhd8ed1ab_0          conda-forge       17kB
#   + hpack                                    4.1.0  pyhd8ed1ab_0          conda-forge       31kB
#   + platformdirs                             4.5.1  pyhcf101f3_0          conda-forge       24kB
#   + distlib                                  0.4.0  pyhd8ed1ab_0          conda-forge      276kB
#   + aiohappyeyeballs                         2.6.1  pyhd8ed1ab_0          conda-forge       20kB
#   + attrs                                   25.4.0  pyhcf101f3_1          conda-forge       65kB
#   + packaging                                 25.0  pyh29332c3_1          conda-forge       62kB
#   + filelock                                3.20.2  pyhd8ed1ab_0          conda-forge       19kB
#   + click                                    8.2.1  pyh707e725_0          conda-forge       88kB
#   + colorama                                 0.4.6  pyhd8ed1ab_1          conda-forge     Cached
#   + zipp                                    3.23.0  pyhcf101f3_1          conda-forge       24kB
#   + typing_extensions                       4.15.0  pyhcf101f3_0          conda-forge       52kB
#   + prometheus_client                       0.23.1  pyhd8ed1ab_0          conda-forge       55kB
#   + charset-normalizer                       3.4.4  pyhd8ed1ab_0          conda-forge       51kB
#   + idna                                      3.11  pyhd8ed1ab_0          conda-forge       51kB
#   + certifi                               2026.1.4  pyhd8ed1ab_0          conda-forge      151kB
#   + pyu2f                                    0.1.5  pyhd8ed1ab_1          conda-forge       37kB
#   + pyasn1-modules                           0.4.2  pyhd8ed1ab_0          conda-forge       96kB
#   + rsa                                      4.9.1  pyhd8ed1ab_0          conda-forge       32kB
#   + h2                                       4.3.0  pyhcf101f3_0          conda-forge       96kB
#   + colorful                                 0.5.8  pyhd8ed1ab_0          conda-forge      175kB
#   + importlib-metadata                       8.7.0  pyhe01879c_1          conda-forge       35kB
#   + typing-inspection                        0.4.2  pyhd8ed1ab_1          conda-forge       19kB
#   + typing-extensions                       4.15.0  h396c80c_0            conda-forge       91kB
#   + virtualenv                             20.35.4  pyhd8ed1ab_0          conda-forge        4MB
#   + annotated-types                          0.7.0  pyhd8ed1ab_1          conda-forge       18kB
#   + rpds-py                                 0.30.0  py313h843e2db_0       conda-forge      383kB
#   + brotli-python                            1.2.0  py313hf159716_1       conda-forge      368kB
#   + backports.zstd                           1.3.0  py313h18e8e13_0       conda-forge      241kB
#   + propcache                                0.3.1  py313h8060acc_0       conda-forge       53kB
#   + multidict                                6.7.0  py313h3dea7bd_0       conda-forge       99kB
#   + frozenlist                               1.7.0  py313h6b9daa2_0       conda-forge       55kB
#   + msgpack-python                           1.1.2  py313h7037e92_1       conda-forge      103kB
#   + wrapt                                   1.17.3  py313h07c4f96_1       conda-forge       65kB
#   + opencensus-context                       0.1.3  py313h78bf25f_4       conda-forge       22kB
#   + protobuf                                6.31.1  py313h8c92afc_2       conda-forge      485kB
#   + grpcio                                  1.73.1  py313h2b3948d_1       conda-forge      897kB
#   + pyyaml                                   6.0.3  py313h3dea7bd_0       conda-forge      207kB
#   + psutil                                   7.2.1  py313h54dd161_0       conda-forge      225kB
#   + cffi                                     2.0.0  py313hf46b229_1       conda-forge      298kB
#   + pydantic-core                           2.41.5  py313h843e2db_1       conda-forge        2MB
#   + yarl                                    1.22.0  py313h3dea7bd_0       conda-forge      150kB
#   + cryptography                            46.0.3  py313heb322e3_1       conda-forge        2MB
#   + referencing                             0.37.0  pyhcf101f3_0          conda-forge       52kB
#   + urllib3                                  2.6.2  pyhd8ed1ab_0          conda-forge      103kB
#   + aiosignal                                1.4.0  pyhd8ed1ab_0          conda-forge       14kB
#   + deprecated                               1.3.1  pyhd8ed1ab_0          conda-forge       16kB
#   + smart_open                               7.5.0  pyhcf101f3_0          conda-forge       57kB
#   + proto-plus                              1.27.0  pyhd8ed1ab_0          conda-forge       43kB
#   + googleapis-common-protos                1.72.0  pyhd8ed1ab_0          conda-forge      143kB
#   + opentelemetry-proto                     1.39.1  pyhd8ed1ab_0          conda-forge       46kB
#   + pydantic                                2.12.5  pyhcf101f3_1          conda-forge      340kB
#   + pyopenssl                               25.3.0  pyhd8ed1ab_0          conda-forge      126kB
#   + jsonschema-specifications             2025.9.1  pyhcf101f3_0          conda-forge       19kB
#   + requests                                2.32.5  pyhcf101f3_1          conda-forge       64kB
#   + opentelemetry-api                       1.39.1  pyhd8ed1ab_0          conda-forge       46kB
#   + jsonschema                              4.25.1  pyhe01879c_0          conda-forge       82kB
#   + opentelemetry-semantic-conventions      0.60b1  pyhd8ed1ab_0          conda-forge      118kB
#   + opentelemetry-sdk                       1.39.1  pyhd8ed1ab_0          conda-forge       85kB
#   + opentelemetry-exporter-prometheus       0.60b1  pyhcf101f3_0          conda-forge       23kB
#   + aiohttp                                 3.13.3  py313hd6074c6_0       conda-forge        1MB
#   + ray-core                                2.53.0  py313h480d956_0       conda-forge       40MB
#   + google-auth                             2.46.0  pyhd8ed1ab_0          conda-forge      130kB
#   + aiohttp-cors                             0.8.1  pyhd8ed1ab_0          conda-forge       26kB
#   + google-api-core                         2.28.1  pyhd8ed1ab_0          conda-forge       98kB
#   + opencensus                              0.11.3  pyhd8ed1ab_1          conda-forge       71kB
#   + ray-default                             2.53.0  py313h9ae69f9_0       conda-forge        2MB
#
#   Summary:
#
#   Install: 106 packages
#
#   Total download: 145MB
#
# ──────────────────────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading  (1)   0%
# Extracting         0%python_abi                                           7.0kB @  82.5kB/s  0.1s
# ca-certificates                                    146.5kB @   1.6MB/s  0.1s
# tzdata                                             119.1kB @   1.3MB/s  0.1s
# [+] 0.1s
# Downloading  (5)   1%
# Extracting   (3)  ⣾  libgcc                                               1.0MB @  10.3MB/s  0.1s
# libgomp                                            603.3kB @   4.9MB/s  0.1s
# libmpdec                                            91.2kB @ 665.3kB/s  0.1s
# bzip2                                              260.3kB @   1.8MB/s  0.1s
# libffi                                              57.8kB @ 355.2kB/s  0.1s
# ncurses                                            891.6kB @   5.5MB/s  0.1s
# libunwind                                           76.0kB @ 405.0kB/s  0.1s
# [+] 0.2s
# Downloading  (5)   3%
# Extracting   (2)  ⣾  zstd                                               601.4kB @   3.0MB/s  0.1s
# libsqlite                                          943.5kB @   4.6MB/s  0.1s
# libre2-11                                          211.1kB @ 977.1kB/s  0.1s
# pyasn1                                              62.2kB @ 266.4kB/s  0.0s
# libgrpc                                              8.3MB @  34.9MB/s  0.1s
# hpack                                               30.7kB @ 122.2kB/s  0.1s
# aiohappyeyeballs                                    19.8kB @  76.8kB/s  0.1s
# filelock                                            18.6kB @  71.6kB/s  0.0s
# idna                                                50.7kB @ 185.9kB/s  0.0s
# typing_extensions                                   51.7kB @ 174.9kB/s  0.1s
# [+] 0.3s
# Downloading  (5)  10%
# Extracting   (3)  ⣾  colorful                                           175.1kB @ 579.9kB/s  0.0s
# pyasn1-modules                                      96.0kB @ 312.3kB/s  0.1s
# rpds-py                                            383.2kB @   1.2MB/s  0.0s
# propcache                                           53.2kB @ 159.1kB/s  0.0s
# psutil                                             225.4kB @ 643.6kB/s  0.0s
# msgpack-python                                     103.1kB @ 288.7kB/s  0.1s
# typing-extensions                                   91.4kB @ 250.9kB/s  0.1s
# protobuf                                           485.1kB @   1.3MB/s  0.1s
# yarl                                               150.5kB @ 402.2kB/s  0.0s
# urllib3                                            102.8kB @ 267.5kB/s  0.0s
# [+] 0.4s
# Downloading  (5)  11%
# Extracting   (1)  ⣾  smart_open                                          56.8kB @ 139.3kB/s  0.1s
# opentelemetry-proto                                 45.9kB @ 110.7kB/s  0.1s
# jsonschema                                          81.7kB @ 194.2kB/s  0.0s
# jsonschema-specifications                           19.2kB @  44.3kB/s  0.1s
# google-auth                                        130.2kB @ 291.2kB/s  0.0s
# opentelemetry-exporter-prometheus                   23.2kB @  51.4kB/s  0.1s
# opencensus                                          70.8kB @ 150.9kB/s  0.1s
# openssl                                              3.2MB @   6.6MB/s  0.1s
# yaml                                                85.2kB @ 174.9kB/s  0.1s
# libabseil                                            1.3MB @   2.7MB/s  0.0s
# [+] 0.5s
# Downloading  (5)  15%
# Extracting   (3)  ⣾  readline                                           345.1kB @ 687.7kB/s  0.1s
# pip                                                  1.2MB @   2.3MB/s  0.0s
# attrs                                               64.8kB @ 121.8kB/s  0.0s
# hyperframe                                          17.4kB @  32.5kB/s  0.0s
# zipp                                                24.2kB @  42.5kB/s  0.1s
# h2                                                  96.0kB @ 167.2kB/s  0.0s
# certifi                                            151.0kB @ 260.5kB/s  0.1s
# [+] 0.6s
# Downloading  (5)  20%
# Extracting   (1)  ⣾  virtualenv                                           4.4MB @   7.4MB/s  0.1s
# libprotobuf                                          4.4MB @   7.2MB/s  0.1s
# wrapt                                               64.9kB @ 105.5kB/s  0.0s
# pyyaml                                             207.1kB @ 332.3kB/s  0.0s
# backports.zstd                                     240.9kB @ 379.5kB/s  0.1s
# deprecated                                          15.8kB @  24.6kB/s  0.0s
# pydantic                                           340.5kB @ 522.6kB/s  0.0s
# cryptography                                         1.7MB @   2.6MB/s  0.1s
# opentelemetry-api                                   46.4kB @  69.6kB/s  0.0s
# google-api-core                                     98.2kB @ 143.9kB/s  0.0s
# libuuid                                             40.3kB @  58.6kB/s  0.0s
# aiohttp                                              1.0MB @   1.5MB/s  0.1s
# [+] 0.7s
# Downloading  (5)  25%
# Extracting   (4)  ⣾  libexpat                                            76.6kB @ 109.1kB/s  0.0s
# ld_impl_linux-64                                   730.8kB @   1.0MB/s  0.0s
# platformdirs                                        23.9kB @  33.1kB/s  0.0s
# re2                                                 27.3kB @  37.6kB/s  0.0s
# pyu2f                                               36.8kB @  49.5kB/s  0.0s
# multidict                                           99.2kB @ 130.9kB/s  0.0s
# typing-inspection                                   18.9kB @  24.7kB/s  0.1s
# grpcio                                             897.1kB @   1.2MB/s  0.0s
# click                                               87.7kB @ 113.9kB/s  0.1s
# referencing                                         51.8kB @  65.7kB/s  0.0s
# [+] 0.8s
# Downloading  (5)  26%
# Extracting   (2)  ⣾  googleapis-common-protos                           143.0kB @ 178.8kB/s  0.0s
# opentelemetry-semantic-conventions                 118.0kB @ 145.5kB/s  0.0s
# opentelemetry-sdk                                   84.6kB @ 103.7kB/s  0.0s
# c-ares                                             207.9kB @ 250.9kB/s  0.1s
# six                                                 18.5kB @  22.1kB/s  0.0s
# packaging                                           62.5kB @  73.3kB/s  0.0s
# rsa                                                 31.7kB @  36.8kB/s  0.0s
# cffi                                               298.4kB @ 342.4kB/s  0.0s
# brotli-python                                      367.7kB @ 415.5kB/s  0.1s
# proto-plus                                          43.1kB @  48.5kB/s  0.0s
# [+] 0.9s
# Downloading  (5)  27%
# Extracting   (2)  ⣾  liblzma                                            112.9kB @ 123.4kB/s  0.0s
# distlib                                            275.6kB @ 294.8kB/s  0.0s
# importlib-metadata                                  34.6kB @  36.6kB/s  0.0s
# py-spy                                               1.8MB @   1.9MB/s  0.1s
# icu                                                 12.7MB @  13.1MB/s  0.2s
# pyopenssl                                          126.4kB @ 128.4kB/s  0.0s
# opencensus-context                                  22.1kB @  22.4kB/s  0.1s
# [+] 1.0s
# Downloading  (5)  44%
# Extracting   (3)  ⣾  charset-normalizer                                  51.0kB @  49.8kB/s  0.0s
# ray-default                                          2.1MB @   2.1MB/s  0.1s
# cachetools                                          16.9kB @  15.7kB/s  0.0s
# aiohttp-cors                                        25.7kB @  23.5kB/s  0.1s
# [+] 1.1s
# Downloading  (5)  59%
# Extracting   (2)  ⣾  pydantic-core                                        1.9MB @   1.7MB/s  0.1s
# frozenlist                                          54.7kB @  48.5kB/s  0.0s
# libstdcxx                                            5.9MB @   5.1MB/s  0.1s
# annotated-types                                     18.1kB @  15.7kB/s  0.0s
# requests                                            63.6kB @  53.4kB/s  0.0s
# tk                                                   3.3MB @   2.8MB/s  0.1s
# prometheus_client                                   54.6kB @  45.5kB/s  0.0s
# [+] 1.2s
# Downloading  (3)  86%
# Extracting   (4)  ⣾  aiosignal                                           13.7kB @  11.2kB/s  0.0s
# ray-core                                            40.4MB @  32.6MB/s  0.4s
# [+] 1.3s
# Downloading  (1)  97%
# Extracting   (1)  ⣾  python                                              37.2MB @  27.3MB/s  0.4s
# [+] 1.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 1.5s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 1.6s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 1.7s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 1.8s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 1.9s
# Downloading      100%
# Extracting   (1)  ⣾
# Downloading and Extracting Packages:
#
# done
# done
# done
#
# To activate this environment, use
#
#      $ mamba activate ray-jupyter
#
# To deactivate an active environment, use
#
#      $ mamba deactivate

# %%
# %%bash
# # You must source the conda profile to make 'activate' work in bash
# source /usr/local/etc/profile.d/conda.sh
# conda activate ray-jupyter
#
# # Any commands you want to run in this environment must be in this SAME cell
# python -c "import ray; print('Ray is running in:', ray.__version__)"
# Out:
# Ray is running in: 2.53.0

# %%
# !curl -LsSf https://astral.sh/uv/install.sh | sh
import os
os.environ['PATH'] = f"{os.environ['HOME']}/.cargo/bin:{os.environ['PATH']}"
# Out:
# curl: /usr/local/lib/libcurl.so.4: no version information available (required by curl)
# downloading uv 0.9.22 x86_64-unknown-linux-gnu
# curl: /usr/local/lib/libcurl.so.4: no version information available (required by curl)
# no checksums to verify
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!

# %%
# !uv init
# !uv add ray[default]
# Out:
# Initialized project `content`
# Using CPython 3.11.11 interpreter at: /usr/local/bin/python3.11
# Creating virtual environment at: .venv
# Resolved 59 packages in 490ms
# Prepared 57 packages in 1.06s
# Installed 57 packages in 65ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.3
#  + aiohttp-cors==0.8.1
#  + aiosignal==1.4.0
#  + annotated-types==0.7.0
#  + attrs==25.4.0
#  + cachetools==6.2.4
#  + certifi==2026.1.4
#  + charset-normalizer==3.4.4
#  + click==8.3.1
#  + colorful==0.5.8
#  + distlib==0.4.0
#  + filelock==3.20.2
#  + frozenlist==1.8.0
#  + google-api-core==2.28.1
#  + google-auth==2.45.0
#  + googleapis-common-protos==1.72.0
#  + grpcio==1.76.0
#  + idna==3.11
#  + importlib-metadata==8.7.1
#  + jsonschema==4.25.1
#  + jsonschema-specifications==2025.9.1
#  + msgpack==1.1.2
#  + multidict==6.7.0
#  + opencensus==0.11.4
#  + opencensus-context==0.1.3
#  + opentelemetry-api==1.39.1
#  + opentelemetry-exporter-prometheus==0.60b1
#  + opentelemetry-proto==1.39.1
#  + opentelemetry-sdk==1.39.1
#  + opentelemetry-semantic-conventions==0.60b1
#  + packaging==25.0
#  + platformdirs==4.5.1
#  + prometheus-client==0.23.1
#  + propcache==0.4.1
#  + proto-plus==1.27.0
#  + protobuf==6.33.2
#  + py-spy==0.4.1
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.2
#  + pydantic==2.12.5
#  + pydantic-core==2.41.5
#  + pyyaml==6.0.3
#  + ray==2.53.0
#  + referencing==0.37.0
#  + requests==2.32.5
#  + rpds-py==0.30.0
#  + rsa==4.9.1
#  + six==1.17.0
#  + smart-open==7.5.0
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.2
#  + urllib3==2.6.2
#  + virtualenv==20.35.4
#  + wrapt==2.0.1
#  + yarl==1.22.0
#  + zipp==3.23.0

# %%
import os
os.environ["RAY_RUNTIME_ENV_HOOK"] = "ray._private.runtime_env.uv_runtime_env_hook.hook"

# %%
# Install uv first
# !curl -LsSf astral.sh | sh
import os
os.environ['PATH'] = f"{os.environ['HOME']}/.cargo/bin:{os.environ['PATH']}"

# Use uv to install your specific list
# !uv pip install pandas notebook ray==2.46.0 ipywidgets numpy torch lightning fastapi xgboost scikit-learn pyarrow torchvision matplotlib s3fs diffusers transformers awscli
# Out:
# curl: /usr/local/lib/libcurl.so.4: no version information available (required by curl)
# sh: 1: Syntax error: redirection unexpected
# curl: (23) Failure writing output to destination, passed 1369 returned 1328
# Using Python 3.11.11 environment at: /usr/local
# Resolved 179 packages in 599ms
# Prepared 139 packages in 1m 08s
# Installed 166 packages in 384ms
#  + aiobotocore==2.26.0
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.3
#  + aioitertools==0.13.0
#  + aiosignal==1.4.0
#  + annotated-doc==0.0.4
#  + annotated-types==0.7.0
#  + anyio==4.12.1
#  + argon2-cffi==25.1.0
#  + argon2-cffi-bindings==25.1.0
#  + arrow==1.4.0
#  + asttokens==3.0.1
#  + async-lru==2.0.5
#  + attrs==25.4.0
#  + awscli==1.43.5
#  + babel==2.17.0
#  + beautifulsoup4==4.14.3
#  + bleach==6.3.0
#  + botocore==1.41.5
#  + click==8.3.1
#  + comm==0.2.3
#  + contourpy==1.3.3
#  + cycler==0.12.1
#  + debugpy==1.8.19
#  + decorator==5.2.1
#  + defusedxml==0.7.1
#  + diffusers==0.36.0
#  + docutils==0.19
#  + executing==2.2.1
#  + fastapi==0.128.0
#  + fastjsonschema==2.21.2
#  + filelock==3.20.2
#  + fonttools==4.61.1
#  + fqdn==1.5.1
#  + frozenlist==1.8.0
#  + fsspec==2025.12.0
#  + h11==0.16.0
#  + hf-xet==1.2.0
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + huggingface-hub==0.36.0
#  + importlib-metadata==8.7.1
#  + ipykernel==7.1.0
#  + ipython==9.9.0
#  + ipython-pygments-lexers==1.1.1
#  + ipywidgets==8.1.8
#  + isoduration==20.11.0
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + jmespath==1.0.1
#  + joblib==1.5.3
#  + json5==0.13.0
#  + jsonschema==4.25.1
#  + jsonschema-specifications==2025.9.1
#  + jupyter-client==8.7.0
#  + jupyter-core==5.9.1
#  + jupyter-events==0.12.0
#  + jupyter-lsp==2.3.0
#  + jupyter-server==2.17.0
#  + jupyter-server-terminals==0.5.3
#  + jupyterlab==4.5.1
#  + jupyterlab-pygments==0.3.0
#  + jupyterlab-server==2.28.0
#  + jupyterlab-widgets==3.0.16
#  + kiwisolver==1.4.9
#  + lark==1.3.1
#  + lightning==2.6.0
#  + lightning-utilities==0.15.2
#  + markupsafe==3.0.3
#  + matplotlib==3.10.8
#  + matplotlib-inline==0.2.1
#  + mistune==3.2.0
#  + mpmath==1.3.0
#  + msgpack==1.1.2
#  + multidict==6.7.0
#  + nbclient==0.10.4
#  + nbconvert==7.16.6
#  + nbformat==5.10.4
#  + nest-asyncio==1.6.0
#  + networkx==3.6.1
#  + notebook==7.5.1
#  + notebook-shim==0.2.4
#  + numpy==2.4.0
#  + nvidia-cublas-cu12==12.8.4.1
#  + nvidia-cuda-cupti-cu12==12.8.90
#  + nvidia-cuda-nvrtc-cu12==12.8.93
#  + nvidia-cuda-runtime-cu12==12.8.90
#  + nvidia-cudnn-cu12==9.10.2.21
#  + nvidia-cufft-cu12==11.3.3.83
#  + nvidia-cufile-cu12==1.13.1.3
#  + nvidia-curand-cu12==10.3.9.90
#  + nvidia-cusolver-cu12==11.7.3.90
#  + nvidia-cusparse-cu12==12.5.8.93
#  + nvidia-cusparselt-cu12==0.7.1
#  + nvidia-nccl-cu12==2.27.5
#  + nvidia-nvjitlink-cu12==12.8.93
#  + nvidia-nvshmem-cu12==3.3.20
#  + nvidia-nvtx-cu12==12.8.90
#  + overrides==7.7.0
#  + pandas==2.3.3
#  + pandocfilters==1.5.1
#  + parso==0.8.5
#  + pexpect==4.9.0
#  + pillow==12.1.0
#  + prometheus-client==0.23.1
#  + prompt-toolkit==3.0.52
#  + propcache==0.4.1
#  + protobuf==6.33.2
#  + psutil==7.2.1
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==22.0.0
#  + pyasn1==0.6.1
#  + pydantic==2.12.5
#  + pydantic-core==2.41.5
#  + pygments==2.19.2
#  + pyparsing==3.3.1
#  + python-dateutil==2.9.0.post0
#  + python-json-logger==4.0.0
#  + pytorch-lightning==2.6.0
#  + pytz==2025.2
#  + pyyaml==6.0.3
#  + pyzmq==27.1.0
#  + ray==2.46.0
#  + referencing==0.37.0
#  + regex==2025.11.3
#  + rfc3339-validator==0.1.4
#  + rfc3986-validator==0.1.1
#  + rfc3987-syntax==1.1.0
#  + rpds-py==0.30.0
#  + rsa==4.7.2
#  + s3fs==2025.12.0
#  + s3transfer==0.15.0
#  + safetensors==0.7.0
#  + scikit-learn==1.8.0
#  + scipy==1.16.3
#  + send2trash==2.0.0
#  + six==1.17.0
#  + soupsieve==2.8.1
#  + stack-data==0.6.3
#  + starlette==0.50.0
#  + sympy==1.14.0
#  + terminado==0.18.1
#  + threadpoolctl==3.6.0
#  + tinycss2==1.4.0
#  + tokenizers==0.22.2
#  + torch==2.9.1
#  + torchmetrics==1.8.2
#  + torchvision==0.24.1
#  + tornado==6.5.4
#  + traitlets==5.14.3
#  + transformers==4.57.3
#  + triton==3.5.1
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.2
#  + tzdata==2025.3
#  + uri-template==1.3.0
#  + wcwidth==0.2.14
#  + webcolors==25.10.0
#  + webencodings==0.5.1
#  + websocket-client==1.9.0
#  + widgetsnbextension==4.0.15
#  + wrapt==1.17.3
#  + xgboost==3.1.2
#  + yarl==1.22.0
#  + zipp==3.23.0

# %%
# !pip install ray
# Out:
# Requirement already satisfied: ray in /usr/local/lib/python3.11/site-packages (2.46.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/site-packages (from ray) (8.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/site-packages (from ray) (3.20.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/site-packages (from ray) (4.25.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/site-packages (from ray) (1.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/site-packages (from ray) (24.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.11/site-packages (from ray) (6.33.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/site-packages (from ray) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/site-packages (from ray) (2.32.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/site-packages (from jsonschema->ray) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/site-packages (from jsonschema->ray) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/site-packages (from jsonschema->ray) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/site-packages (from jsonschema->ray) (0.30.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests->ray) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->ray) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests->ray) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->ray) (2024.12.14)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/site-packages (from referencing>=0.28.4->jsonschema->ray) (4.15.0)

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !pip list | grep ray
# Out:
# ray                       2.46.0

# %%
import sys
print(sys.executable)
# Out:
# /usr/bin/python3.real

# %%
import ray
ray.init()

@ray.remote
def hello_world():
  return "Ray is working"

result = ray.get(hello_world.remote())
print(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1575909447.py in <cell line: 0>()
# ----> 1 import ray
#       2 ray.init()
#       3
#       4 @ray.remote
#       5 def hello_world():
#
# ModuleNotFoundError: No module named 'ray'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
