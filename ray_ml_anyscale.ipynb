# %% [markdown]
# <a href="https://colab.research.google.com/github/pareshpawar2915-source/unlocking-dbt/blob/main/ray_ml_anyscale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda --version
# Out:
# conda 24.11.2

# %%
# !mamba install python=3.13 ray-default -c conda-forge
# Out:
# Looking for: ['python=3.13', 'ray-default']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# Your pinning does not match what's currently installed. Please remove the pin and fix your installation
#   Pin: python=3.12
#   Currently installed: conda-forge/linux-64::python==3.11.11=h9e4cc4f_1_cpython

# %%
# !mamba create -n ray-jupyter python=3.13 ray-default -y
# Out:
# Looking for: ['python=3.13', 'ray-default']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# Transaction
#
#   Prefix: /usr/local/envs/ray-jupyter
#
#   Updating specs:
#
#    - python=3.13
#    - ray-default
#
#
#   Package                                  Version  Build                 Channel           Size
# ──────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────────────────────────
#
#   + python_abi                                3.13  8_cp313               conda-forge     Cached
#   + tzdata                                   2025c  hc9c84f9_1            conda-forge     Cached
#   + ca-certificates                       2026.1.4  hbd8a1cb_0            conda-forge     Cached
# ...

# %%
# %%bash
# # You must source the conda profile to make 'activate' work in bash
# source /usr/local/etc/profile.d/conda.sh
# conda activate ray-jupyter
#
# # Any commands you want to run in this environment must be in this SAME cell
# python -c "import ray; print('Ray is running in:', ray.__version__)"
# Out:
# Ray is running in: 2.53.0

# %%
# !curl -LsSf https://astral.sh/uv/install.sh | sh
import os
os.environ['PATH'] = f"{os.environ['HOME']}/.cargo/bin:{os.environ['PATH']}"
# Out:
# curl: /usr/local/lib/libcurl.so.4: no version information available (required by curl)
# downloading uv 0.9.22 x86_64-unknown-linux-gnu
# curl: /usr/local/lib/libcurl.so.4: no version information available (required by curl)
# no checksums to verify
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!

# %%
# !uv init
# !uv add ray[default]
# Out:
# error: Project is already initialized in `/content` (`pyproject.toml` file exists)
# Resolved 59 packages in 0.47ms
# Audited 57 packages in 0.84ms

# %%
import os
os.environ["RAY_RUNTIME_ENV_HOOK"] = "ray._private.runtime_env.uv_runtime_env_hook.hook"

# %%
# Install uv first
# !curl -LsSf astral.sh | sh
import os
os.environ['PATH'] = f"{os.environ['HOME']}/.cargo/bin:{os.environ['PATH']}"

# Use uv to install your specific list
# !uv pip install pandas notebook ray==2.46.0 ipywidgets numpy torch lightning fastapi xgboost scikit-learn pyarrow torchvision matplotlib s3fs diffusers transformers awscli
# Out:
# curl: /usr/local/lib/libcurl.so.4: no version information available (required by curl)
# sh: 1: Syntax error: redirection unexpected
# curl: (23) Failure writing output to destination, passed 1369 returned 1341
# Using Python 3.11.11 environment at: /usr/local
# Audited 17 packages in 16ms

# %%
# !pip install ray

# %%
import ray
ray.init()

@ray.remote
def hello_world():
  return "Ray is working"

result = ray.get(hello_world.remote())
print(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1575909447.py in <cell line: 0>()
# ----> 1 import ray
#       2 ray.init()
#       3
#       4 @ray.remote
#       5 def hello_world():
#
# ModuleNotFoundError: No module named 'ray'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !pip list | grep ray
# Out:
# ray                       2.46.0

# %%
# 1. Install and init condacolab
# !pip install -q condacolab
import condacolab
condacolab.install()

# --- STOP HERE: Wait for the kernel to restart automatically ---
# Out:
# ✨🍰✨ Everything looks OK!

# %%
condacolab.install_from_url("repo.anaconda.com")
# Out:
# ✨🍰✨ Everything looks OK!

# %%
import sys
import os

# Manually insert the Conda path at the very beginning of the search list
conda_path = "/usr/local/lib/python3.12/site-packages" # or 3.11 depending on your version
if conda_path not in sys.path:
    sys.path.insert(0, conda_path)

# Update environment variables for the shell
os.environ["PATH"] = "/usr/local/bin:" + os.environ["PATH"]

# Verify
import ray
print(f"Ray is now found at: {ray.__file__}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2768203300.py in <cell line: 0>()
#      11
#      12 # Verify
# ---> 13 import ray
#      14 print(f"Ray is now found at: {ray.__file__}")
#
# ModuleNotFoundError: No module named 'ray'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import ray
ray.init()

@ray.remote
def hello_world():
  return "Ray is working"

result = ray.get(hello_world.remote())
print(result)
